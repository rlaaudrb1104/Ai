# %% [markdown]
# <a href="https://colab.research.google.com/github/rlaaudrb1104/Ai/blob/LEE/plus_data(PHP).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import csv
from google.colab import drive

# Google Drive 마운트
drive.mount('/content/drive')

def json_to_csv(json_file, csv_file):
    try:
        with open(json_file, 'r', encoding='utf-8') as jfile:
            data = json.load(jfile)
    except json.decoder.JSONDecodeError as e:
        print(f"Error decoding JSON in file: {json_file}")
        print(f"Error message: {str(e)}")
        return

    # CSV 파일 쓰기
    with open(csv_file, 'w', newline='', encoding='utf-8') as cfile:
        writer = csv.writer(cfile)

        # CSV 파일의 헤더를 쓰기
        writer.writerow(data[0].keys())

        # JSON 데이터를 CSV 파일에 쓰기
        for item in data:
            writer.writerow(item.values())

# JSON 파일과 CSV 파일 경로 지정
json_file_path = '/content/drive/MyDrive/plus_data/data_PHP_vul.json'
csv_file_path = '/content/drive/MyDrive/plus_data/data_PHP_vul.csv'

# JSON 파일을 CSV 파일로 변환
json_to_csv(json_file_path, csv_file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# CSV 파일 경로
file_path = '/content/drive/MyDrive/plus_data/data_PHP_vul.csv'

# 원본 데이터프레임 불러오기
df = pd.read_csv(file_path)

# 필요한 컬럼 선택
selected_columns = ['cwe_id', 'code', 'is_vulnerable', 'programming_language']
new_df = df[selected_columns]

# 결과 출력
print(new_df)
# Out:
#         cwe_id                                               code  \
# 0       CWE-79  \tfunction block_email_request($email) {\r\n\t...
# 1       CWE-79  \tfunction change_email_request() {\r\n\t\tif ...
# 2       CWE-79  \t\t\t$email = strtolower($comment_author_emai...
# 3       CWE-79  \tfunction manage_link($email='', $html=true, ...
# 4       CWE-79  \t\t\t\t$this->{$var} = trim($_REQUEST[$var]);...
# ...        ...                                                ...
# 6691  CWE-1241  \tfunction insertNewRSSToken($userId, $context...
# 6692  CWE-1241  \tfunction insertToken($token) {\n\t\tdo {\n\t...
# 6693  CWE-1241  \tpublic function extractPlugin($filePath, $or...
# 6694  CWE-1241  \tpublic static function generatePassword($len...
# 6695  CWE-1241  \tfunction getCSRFToken() {\n\t\t$csrf = $this...
#
#       is_vulnerable programming_language
# 0              True                  PHP
# 1              True                  PHP
# 2              True                  PHP
# 3              True                  PHP
# 4              True                  PHP
# ...             ...                  ...
# 6691           True                  PHP
# 6692           True                  PHP
# 6693           True                  PHP
# 6694           True                  PHP
# 6695           True                  PHP
#
# [6696 rows x 4 columns]

# %%
new_df
# Out:
#         cwe_id                                               code  \
# 0       CWE-79  \tfunction block_email_request($email) {\r\n\t...
# 1       CWE-79  \tfunction change_email_request() {\r\n\t\tif ...
# 2       CWE-79  \t\t\t$email = strtolower($comment_author_emai...
# 3       CWE-79  \tfunction manage_link($email='', $html=true, ...
# 4       CWE-79  \t\t\t\t$this->{$var} = trim($_REQUEST[$var]);...
# ...        ...                                                ...
# 6691  CWE-1241  \tfunction insertNewRSSToken($userId, $context...
# 6692  CWE-1241  \tfunction insertToken($token) {\n\t\tdo {\n\t...
# 6693  CWE-1241  \tpublic function extractPlugin($filePath, $or...
# 6694  CWE-1241  \tpublic static function generatePassword($len...
# 6695  CWE-1241  \tfunction getCSRFToken() {\n\t\t$csrf = $this...
#
#       is_vulnerable programming_language
# 0              True                  PHP
# 1              True                  PHP
# 2              True                  PHP
# 3              True                  PHP
# 4              True                  PHP
# ...             ...                  ...
# 6691           True                  PHP
# 6692           True                  PHP
# 6693           True                  PHP
# 6694           True                  PHP
# 6695           True                  PHP
#
# [6696 rows x 4 columns]

# %%
df_counts = new_df['cwe_id'].value_counts()

df_counts.head(50)
# Out:
# cwe_id
# CWE-89            2424
# CWE-79            1284
# CWE-639            424
# CWE-74             421
# CWE-20             304
# CWE-352            272
# CWE-22             214
# CWE-200            122
# CWE-400            116
# NVD-CWE-noinfo      71
# CWE-434             70
# CWE-502             67
# CWE-78              66
# NVD-CWE-Other       54
# CWE-862             52
# CWE-384             50
# CWE-94              48
# CWE-330             46
# CWE-918             43
# CWE-601             36
# CWE-863             36
# CWE-264             35
# CWE-327             32
# CWE-88              31
# CWE-640             25
# CWE-732             23
# CWE-798             21
# CWE-307             18
# CWE-287             18
# CWE-1236            16
# CWE-269             15
# CWE-532             14
# CWE-116             14
# CWE-281             12
# CWE-521             12
# CWE-29              12
# CWE-829             11
# CWE-613             11
# CWE-73              11
# CWE-707              8
# CWE-668              7
# CWE-212              7
# CWE-565              7
# CWE-319              6
# CWE-1241             6
# CWE-190              6
# CWE-77               5
# CWE-754              5
# CWE-347              5
# CWE-611              4
# Name: count, dtype: int64

# %%
import json
import csv
from google.colab import drive

# Google Drive 마운트
drive.mount('/content/drive')

def json_to_csv(json_file, csv_file):
    try:
        with open(json_file, 'r', encoding='utf-8') as jfile:
            data = json.load(jfile)
    except json.decoder.JSONDecodeError as e:
        print(f"Error decoding JSON in file: {json_file}")
        print(f"Error message: {str(e)}")
        return

    # CSV 파일 쓰기
    with open(csv_file, 'w', newline='', encoding='utf-8') as cfile:
        writer = csv.writer(cfile)

        # CSV 파일의 헤더를 쓰기
        writer.writerow(data[0].keys())

        # JSON 데이터를 CSV 파일에 쓰기
        for item in data:
            writer.writerow(item.values())

# JSON 파일과 CSV 파일 경로 지정
json_file_path = '/content/drive/MyDrive/plus_data/data_PHP_patch.json'
csv_file_path = '/content/drive/MyDrive/plus_data/data_PHP_patch.csv'

# JSON 파일을 CSV 파일로 변환
json_to_csv(json_file_path, csv_file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# CSV 파일 경로
file_path = '/content/drive/MyDrive/plus_data/data_PHP_patch.csv'

# 원본 데이터프레임 불러오기
df = pd.read_csv(file_path)

# 필요한 컬럼 선택
selected_columns = ['cwe_id', 'code', 'is_vulnerable', 'programming_language']
new2_df = df[selected_columns]

# 결과 출력
print(new2_df)
# Out:
#        cwe_id                                               code  \
# 0         NaN  \tfunction block_email_request($email) {\r\n\t...
# 1         NaN  \tfunction change_email_request() {\r\n\t\tif ...
# 2         NaN  \tfunction manage_link($email='', $html=true, ...
# 3         NaN  function show_manual_subscription_form () {\r\...
# 4         NaN      public function recipient($address)\n    {...
# ...       ...                                                ...
# 26082     NaN  \tfunction insertNewRSSToken($userId, $context...
# 26083     NaN  \tfunction insertToken($token) {\n\t\tdo {\n\t...
# 26084     NaN  \tpublic function extractPlugin($filePath, $or...
# 26085     NaN  \tpublic static function generatePassword($len...
# 26086     NaN  \tfunction getCSRFToken() {\n\t\t$csrf = $this...
#
#        is_vulnerable programming_language
# 0              False                  PHP
# 1              False                  PHP
# 2              False                  PHP
# 3              False                  PHP
# 4              False                  PHP
# ...              ...                  ...
# 26082          False                  PHP
# 26083          False                  PHP
# 26084          False                  PHP
# 26085          False                  PHP
# 26086          False                  PHP
#
# [26087 rows x 4 columns]

# %%
new2_df
# Out:
#        cwe_id                                               code  \
# 0         NaN  \tfunction block_email_request($email) {\r\n\t...
# 1         NaN  \tfunction change_email_request() {\r\n\t\tif ...
# 2         NaN  \tfunction manage_link($email='', $html=true, ...
# 3         NaN  function show_manual_subscription_form () {\r\...
# 4         NaN      public function recipient($address)\n    {...
# ...       ...                                                ...
# 26082     NaN  \tfunction insertNewRSSToken($userId, $context...
# 26083     NaN  \tfunction insertToken($token) {\n\t\tdo {\n\t...
# 26084     NaN  \tpublic function extractPlugin($filePath, $or...
# 26085     NaN  \tpublic static function generatePassword($len...
# 26086     NaN  \tfunction getCSRFToken() {\n\t\t$csrf = $this...
#
#        is_vulnerable programming_language
# 0              False                  PHP
# 1              False                  PHP
# 2              False                  PHP
# 3              False                  PHP
# 4              False                  PHP
# ...              ...                  ...
# 26082          False                  PHP
# 26083          False                  PHP
# 26084          False                  PHP
# 26085          False                  PHP
# 26086          False                  PHP
#
# [26087 rows x 4 columns]

# %%
df_counts = new2_df['cwe_id'].value_counts()

df_counts.head(50)
# Out:
# Series([], Name: count, dtype: int64)

# %%
import pandas as pd

# 컬럼 이름 변경
new_df.rename(columns={'cwe_id': 'CWE ID', 'is_vulnerable': 'vul', 'programming_language': 'lang'}, inplace=True)

# 특정 컬럼 값 변경
new_df['vul'] = 1

# 결과 출력
print(new_df)
# Out:
#         CWE ID                                               code  vul lang
# 0       CWE-79  \tfunction block_email_request($email) {\r\n\t...    1  PHP
# 1       CWE-79  \tfunction change_email_request() {\r\n\t\tif ...    1  PHP
# 2       CWE-79  \t\t\t$email = strtolower($comment_author_emai...    1  PHP
# 3       CWE-79  \tfunction manage_link($email='', $html=true, ...    1  PHP
# 4       CWE-79  \t\t\t\t$this->{$var} = trim($_REQUEST[$var]);...    1  PHP
# ...        ...                                                ...  ...  ...
# 6691  CWE-1241  \tfunction insertNewRSSToken($userId, $context...    1  PHP
# 6692  CWE-1241  \tfunction insertToken($token) {\n\t\tdo {\n\t...    1  PHP
# 6693  CWE-1241  \tpublic function extractPlugin($filePath, $or...    1  PHP
# 6694  CWE-1241  \tpublic static function generatePassword($len...    1  PHP
# 6695  CWE-1241  \tfunction getCSRFToken() {\n\t\t$csrf = $this...    1  PHP
#
# [6696 rows x 4 columns]

# %%
import pandas as pd

# 컬럼 이름 변경
new2_df.rename(columns={'cwe_id': 'CWE ID', 'is_vulnerable': 'vul', 'programming_language': 'lang'}, inplace=True)

# 특정 컬럼 값 변경
new2_df['vul'] = 0

# 결과 출력
print(new2_df)
# Out:
#        CWE ID                                               code  vul lang
# 0         NaN  \tfunction block_email_request($email) {\r\n\t...    0  PHP
# 1         NaN  \tfunction change_email_request() {\r\n\t\tif ...    0  PHP
# 2         NaN  \tfunction manage_link($email='', $html=true, ...    0  PHP
# 3         NaN  function show_manual_subscription_form () {\r\...    0  PHP
# 4         NaN      public function recipient($address)\n    {...    0  PHP
# ...       ...                                                ...  ...  ...
# 26082     NaN  \tfunction insertNewRSSToken($userId, $context...    0  PHP
# 26083     NaN  \tfunction insertToken($token) {\n\t\tdo {\n\t...    0  PHP
# 26084     NaN  \tpublic function extractPlugin($filePath, $or...    0  PHP
# 26085     NaN  \tpublic static function generatePassword($len...    0  PHP
# 26086     NaN  \tfunction getCSRFToken() {\n\t\t$csrf = $this...    0  PHP
#
# [26087 rows x 4 columns]
# <ipython-input-17-f28d2cd8428f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_df.rename(columns={'cwe_id': 'CWE ID', 'is_vulnerable': 'vul', 'programming_language': 'lang'}, inplace=True)
# <ipython-input-17-f28d2cd8428f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_df['vul'] = 0

# %%
combined_df = pd.concat([new_df, new2_df], axis=0)

# %%
combined_df
# Out:
#        CWE ID                                               code  vul lang
# 0      CWE-79  \tfunction block_email_request($email) {\r\n\t...    1  PHP
# 1      CWE-79  \tfunction change_email_request() {\r\n\t\tif ...    1  PHP
# 2      CWE-79  \t\t\t$email = strtolower($comment_author_emai...    1  PHP
# 3      CWE-79  \tfunction manage_link($email='', $html=true, ...    1  PHP
# 4      CWE-79  \t\t\t\t$this->{$var} = trim($_REQUEST[$var]);...    1  PHP
# ...       ...                                                ...  ...  ...
# 26082     NaN  \tfunction insertNewRSSToken($userId, $context...    0  PHP
# 26083     NaN  \tfunction insertToken($token) {\n\t\tdo {\n\t...    0  PHP
# 26084     NaN  \tpublic function extractPlugin($filePath, $or...    0  PHP
# 26085     NaN  \tpublic static function generatePassword($len...    0  PHP
# 26086     NaN  \tfunction getCSRFToken() {\n\t\t$csrf = $this...    0  PHP
#
# [32783 rows x 4 columns]

# %%
combined_df.to_csv('/content/drive/MyDrive/plus_data/PHP_vul_patch.csv',index=False)

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/plus_data/PHP_vul_patch.csv')

df
# Out:
#        CWE ID                                               code  vul lang
# 0      CWE-79  \tfunction block_email_request($email) {\r\n\t...    1  PHP
# 1      CWE-79  \tfunction change_email_request() {\r\n\t\tif ...    1  PHP
# 2      CWE-79  \t\t\t$email = strtolower($comment_author_emai...    1  PHP
# 3      CWE-79  \tfunction manage_link($email='', $html=true, ...    1  PHP
# 4      CWE-79  \t\t\t\t$this->{$var} = trim($_REQUEST[$var]);...    1  PHP
# ...       ...                                                ...  ...  ...
# 32778     NaN  \tfunction insertNewRSSToken($userId, $context...    0  PHP
# 32779     NaN  \tfunction insertToken($token) {\n\t\tdo {\n\t...    0  PHP
# 32780     NaN  \tpublic function extractPlugin($filePath, $or...    0  PHP
# 32781     NaN  \tpublic static function generatePassword($len...    0  PHP
# 32782     NaN  \tfunction getCSRFToken() {\n\t\t$csrf = $this...    0  PHP
#
# [32783 rows x 4 columns]

# %%
columns = ['CWE ID', 'vul']
df_counts = df[columns].value_counts()

df_counts.head(50)
# Out:
# CWE ID          vul
# CWE-89          1      2424
# CWE-79          1      1284
# CWE-639         1       424
# CWE-74          1       421
# CWE-20          1       304
# CWE-352         1       272
# CWE-22          1       214
# CWE-200         1       122
# CWE-400         1       116
# NVD-CWE-noinfo  1        71
# CWE-434         1        70
# CWE-502         1        67
# CWE-78          1        66
# NVD-CWE-Other   1        54
# CWE-862         1        52
# CWE-384         1        50
# CWE-94          1        48
# CWE-330         1        46
# CWE-918         1        43
# CWE-863         1        36
# CWE-601         1        36
# CWE-264         1        35
# CWE-327         1        32
# CWE-88          1        31
# CWE-640         1        25
# CWE-732         1        23
# CWE-798         1        21
# CWE-287         1        18
# CWE-307         1        18
# CWE-1236        1        16
# CWE-269         1        15
# CWE-116         1        14
# CWE-532         1        14
# CWE-281         1        12
# CWE-521         1        12
# CWE-29          1        12
# CWE-73          1        11
# CWE-613         1        11
# CWE-829         1        11
# CWE-707         1         8
# CWE-212         1         7
# CWE-668         1         7
# CWE-565         1         7
# CWE-1241        1         6
# CWE-190         1         6
# CWE-319         1         6
# CWE-754         1         5
# CWE-347         1         5
# CWE-77          1         5
# CWE-611         1         4
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/plus_data/PHP_vul_patch.csv')
