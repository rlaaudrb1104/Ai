# %% [markdown]
# <a href="https://colab.research.google.com/github/rlaaudrb1104/Ai/blob/LEE/DATASET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MSR_data_cleaned.csv')
train
# Out:
# <ipython-input-37-d8ea25f68690>:3: DtypeWarning: Columns (20,22,23,27,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MSR_data_cleaned.csv')
#         Unnamed: 0 Access Gained Attack Origin Authentication Required  \
# 0                0          None        Remote           Single system
# 1                1          None        Remote           Single system
# 2                2          None        Remote           Single system
# 3                3          None        Remote           Single system
# 4                4          None        Remote           Single system
# ...            ...           ...           ...                     ...
# 188631      188631          None        Remote            Not required
# 188632      188632          None        Remote            Not required
# 188633      188633          None        Remote            Not required
# ...

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'Access Gained', 'Attack Origin',
#        'Authentication Required', 'Availability', 'CVE ID', 'CVE Page',
#        'CWE ID', 'Complexity', 'Confidentiality', 'Integrity',
#        'Known Exploits', 'Publish Date', 'Score', 'Summary', 'Update Date',
#        'Vulnerability Classification', 'add_lines', 'codeLink', 'commit_id',
#        'commit_message', 'del_lines', 'file_name', 'files_changed',
#        'func_after', 'func_before', 'lang', 'lines_after', 'lines_before',
#        'parentID', 'patch', 'project', 'project_after', 'project_before',
#        'vul', 'vul_func_with_fix'],
#       dtype='object')

# %%
columns = ['CWE ID','CVE ID','func_before','func_after','vul', 'vul_func_with_fix','lang']


train = train[columns]
train.columns
train.to_csv('MSR_dataset.csv',index=False)

# %%
train.isnull().sum()
# Out:
# Unnamed: 0                           0
# Access Gained                    14022
# Attack Origin                    14022
# Authentication Required          14022
# Availability                     14022
# CVE ID                           13440
# CVE Page                         14022
# CWE ID                           36205
# Complexity                       14022
# Confidentiality                  14022
# Integrity                        14022
# Known Exploits                  188636
# Publish Date                     14022
# Score                            14022
# Summary                          14022
# Update Date                          0
# Vulnerability Classification     55916
# add_lines                            0
# codeLink                             0
# commit_id                            0
# commit_message                   19651
# del_lines                            0
# file_name                        19065
# files_changed                    19065
# ...

# %%
import pandas as pd

train = pd.read_csv('/content/MSR_dataset.csv')
train
# Out:
#          CWE ID         CVE ID  \
# 0       CWE-264  CVE-2015-8467
# 1       CWE-264  CVE-2015-8467
# 2       CWE-264  CVE-2015-8467
# 3       CWE-264  CVE-2015-8467
# 4       CWE-264  CVE-2015-8467
# ...         ...            ...
# 188631  CWE-119  CVE-2016-0835
# 188632  CWE-119  CVE-2016-0835
# 188633  CWE-200  CVE-2017-0402
# 188634  CWE-125  CVE-2018-9503
# 188635  CWE-125  CVE-2018-9503
#
#                                               func_before  \
# 0       static bool check_rodc_critical_attribute(stru...
# 1       static int samldb_add_entry(struct samldb_ctx ...
# 2       static int samldb_add_entry_callback(struct ld...
# 3       static int samldb_add_handle_msDS_IntId(struct...
# 4       static int samldb_add_step(struct samldb_ctx *...
# ...                                                   ...
# 188631  void impeg2d_dec_p_mb_params(dec_state_t *ps_d...
# 188632  void impeg2d_dec_pnb_mb_params(dec_state_t *ps...
# ...

# %%
train['CWE ID'].value_counts().head(60)
# Out:
# CWE-119     26497
# CWE-20      20501
# CWE-399     14806
# CWE-264     12487
# CWE-416      9780
# CWE-200      8636
# CWE-125      7717
# CWE-189      6964
# CWE-362      6073
# CWE-476      4572
# CWE-190      3671
# CWE-254      3000
# CWE-787      2918
# CWE-284      2425
# CWE-732      1480
# CWE-310      1478
# CWE-400      1282
# CWE-772      1205
# CWE-59       1049
# CWE-617      1026
# CWE-415       993
# CWE-269       930
# CWE-404       916
# CWE-704       908
# CWE-79        877
# CWE-835       864
# CWE-369       740
# CWE-19        723
# CWE-22        690
# CWE-17        684
# CWE-134       656
# CWE-287       594
# CWE-611       459
# CWE-285       446
# CWE-754       387
# CWE-834       327
# CWE-388       294
# CWE-78        278
# CWE-311       276
# CWE-77        228
# CWE-89        214
# CWE-94        180
# CWE-320       129
# CWE-93         99
# CWE-120        96
# CWE-532        89
# CWE-601        82
# CWE-436        80
# CWE-330        77
# CWE-255        73
# ...

# %%
null_cwe_ids = train[train['CWE ID'].isnull()]
null_cwe_ids
# Out:
#        CWE ID         CVE ID  \
# 227       NaN  CVE-2013-6051
# 228       NaN  CVE-2013-6051
# 229       NaN  CVE-2013-6051
# 230       NaN  CVE-2013-6051
# 231       NaN  CVE-2013-6051
# ...       ...            ...
# 188088    NaN  CVE-2017-0393
# 188089    NaN  CVE-2017-0393
# 188090    NaN  CVE-2017-0393
# 188091    NaN  CVE-2017-0392
# 188092    NaN  CVE-2017-0391
#
#                                               func_before  \
# 227     attr_count (void)\n{\n  return attrhash->count...
# 228     attr_show_all (struct vty *vty)\n{\n  hash_ite...
# 229     attr_show_all_iterator (struct hash_backet *ba...
# 230     attr_unknown_count (void)\n{\n  return transit...
# 231     attrhash_cmp (const void *p1, const void *p2)\...
# ...                                                   ...
# 188088  int vp8dx_receive_compressed_data(VP8D_COMP *p...
# 188089  void vp8_decoder_remove_threads(VP8D_COMP *pbi...
# 188090  void vp8mt_de_alloc_temp_buffers(VP8D_COMP *pb...
# ...

# %%
null_cve_ids = train[train['CVE ID'].isnull()]
null_cve_ids
# Out:
#        CWE ID CVE ID                                        func_before  \
# 97088     NaN    NaN    void FillForm(std::string node_id, std::stri...
# 97089     NaN    NaN    wstring GetTabTitle() {\n    wstring title;\...
# 97090     NaN    NaN    GURL GetTabURL() {\n    GURL url;\n    EXPEC...
# 97091     NaN    NaN    void JavascriptGo(std::string distance) {\n ...
# 97092     NaN    NaN     virtual void SetUp() {\n    UITest::SetUp()...
# ...       ...    ...                                                ...
# 187153    NaN    NaN   float ScrollableShelfView::CalculatePageScrol...
# 187154    NaN    NaN  int ScrollableShelfView::CalculateScrollUpperB...
# 187155    NaN    NaN  void ScrollableShelfView::Layout() {\n  const ...
# 187164    NaN    NaN   void BaseAudioContext::ContextDestroyed(Execu...
# 187165    NaN    NaN  void OfflineAudioDestinationHandler::NotifyCom...
#
#                                                func_after  vul  \
# ...

# %%
null_cve_ids = null_cve_ids[null_cve_ids["vul"] == 0]
null_cve_ids
# Out:
#        CWE ID CVE ID                                        func_before  \
# 97088     NaN    NaN    void FillForm(std::string node_id, std::stri...
# 97089     NaN    NaN    wstring GetTabTitle() {\n    wstring title;\...
# 97090     NaN    NaN    GURL GetTabURL() {\n    GURL url;\n    EXPEC...
# 97091     NaN    NaN    void JavascriptGo(std::string distance) {\n ...
# 97092     NaN    NaN     virtual void SetUp() {\n    UITest::SetUp()...
# ...       ...    ...                                                ...
# 167460    NaN    NaN  OfflineAudioDestinationNode::OfflineAudioDesti...
# 167461    NaN    NaN  void OfflineAudioDestinationHandler::PrepareTa...
# 167462    NaN    NaN  bool OfflineAudioDestinationHandler::RenderIfN...
# 167463    NaN    NaN  void OfflineAudioDestinationHandler::StartOffl...
# 167464    NaN    NaN  void OfflineAudioDestinationHandler::StopRende...
#
#                                                func_after  vul  \
# ...

# %%
len(null_cve_ids)
# Out:
# 12638
